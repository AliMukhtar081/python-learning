# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xarray=np.array([1,25])
yarray=np.array([1,250])
plt.plot(xarray,yarray,'o')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("X Y relation")
plt.grid()
plt.show()

# %%
xarray=np.array([1,2,3,4 ,9,10])
yarray=np.array([1,2,3,4 ,9,10])
plt.scatter(xarray,yarray)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("X Y relation")
plt.grid()
plt.show()

# %%
xarray=np.array(["A","B","C"])
yarray=np.array([1,4,5])
plt.bar(xarray,yarray)
plt.xlabel("Sections")
plt.ylabel("Students")
# Out:
# Text(0, 0.5, 'Students')

# %%
xarray=np.array(["A","B","C"])
yarray=np.array([1,4,5])
plt.pie(yarray,labels=xarray)
plt.legend()
plt.show

# %%
xarray=np.array([1,2,4,5,6,7,8])
plt.boxplot(xarray)
plt.show()
